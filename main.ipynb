# %% [markdown]
# <a href="https://colab.research.google.com/github/ironcevic/plot_tools/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Execute this cell by clicking on the "play" button to get started.

# !git clone https://github.com/ironcevic/plot_tools.git
# !mv plot_tools/* .
# !rm -rf plot_tools
from broadening import *

# %%
# This cell plots the spectrum and saves it as a pdf file.

# Add points here if you want to change the wavelength range.
nm_ticks = np.array((400, 500, 600, 800, 1000, 1500, 3000))

# To plot your data, you can create your own text files and change the names
# in the command below, or edit the example files by replacing the data there
# with your own. You can also control the plotting limits and broadening.
# Good luck!

broaden(singlet_name="singlet_example", triplet_name="triplet_example",
        e_min=0.0, e_max=3.0, energy="eV", broadening=0.2, nm_ticks=nm_ticks,
        visible=False)
